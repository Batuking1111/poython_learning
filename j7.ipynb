# %%
not 8 in [1,2,3,4,5,6,7]
# Out:
# True

# %%
liste = [1,2,3,4,5,6]
for eleman in liste:
    print("Eleman: ",eleman)
# Out:
# Eleman:  1
# Eleman:  2
# Eleman:  3
# Eleman:  4
# Eleman:  5
# Eleman:  6

# %%
a = 0
for topla in liste:
    a =a + topla
    print("Eleman: ",topla)
print(a)
# Out:
# Eleman:  1
# Eleman:  2
# Eleman:  3
# Eleman:  4
# Eleman:  5
# Eleman:  6
# 21

# %%
liste2 = [2,346,236,23,6,236,12,56,2347,246,312,6,5,3,99,5,1]
for value in liste2:
    if value % 2 == 0:
        print("Bu çift bir sayıdır:",value)
# Out:
# Bu çift bir sayıdır: 2
# Bu çift bir sayıdır: 346
# Bu çift bir sayıdır: 236
# Bu çift bir sayıdır: 6
# Bu çift bir sayıdır: 236
# Bu çift bir sayıdır: 12
# Bu çift bir sayıdır: 56
# Bu çift bir sayıdır: 246
# Bu çift bir sayıdır: 312
# Bu çift bir sayıdır: 6

# %%
s = "Python"
for i in s:
    print(i*4)
# Out:
# PPPP
# yyyy
# tttt
# hhhh
# oooo
# nnnn

# %%
liste3 = [(1,2),(3,4),(5,6),(7,8)]
for i in liste3:
    for e in i:
        print(e)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
liste4 = [(1,2),(3,4),(5,6),(7,8)]
for (i,j) in liste4:
    print(i,j)
# Out:
# 1 2
# 3 4
# 5 6
# 7 8

# %%
sözlük = {"bir":1,"iki":2,"üç":3}
for (i,j) in sözlük.items():
    print(i,j)
# Out:
# bir 1
# iki 2
# üç 3
