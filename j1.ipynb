# %%
33
# Out:
# 33

# %%
print(34)
# Out:
# 34

# %%
print(3.5)
# Out:
# 3.5

# %%
print("Batu")
# Out:
# Batu

# %%
print(42,414,4242.424,"Batu")
# Out:
# 42 414 4242.424 Batu

# %%
print("Batuhnın \nbu gün \ndersi var")
# Out:
# Batuhnın
# bu gün
# dersi var

# %%
print("Batuha'nın\tdersi\tvar")
# Out:
# Batuha'nın	dersi	var

# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
print(type("Batu"))
# Out:
# <class 'str'>

# %%
print(23,523,52352,35,sep=" BB ")
# Out:
# 23 BB 523 BB 52352 BB 35

# %%
print("Batu","Han","Erkan",sep = "\n")
# Out:
# Batu
# Han
# Erkan

# %%
print(*"Batuhan")
# Out:
# B a t u h a n

# %%
print(*"Batuhan",sep = "/")
# Out:
# B/a/t/u/h/a/n

# %%
print(*"Batuah erkan",sep="\t")
# Out:
# B	a	t	u	a	h	 	e	r	k	a	n

# %%
f = "{} {} {}"
print(f.format("Merhaba",2,"Dünya"))
# Out:
# Merhaba 2 Dünya

# %%
a = 3
b = 4
print("{1} + {0} eşittir {2}".format(a,b,a+b))
# Out:
# 4 + 3 eşittir 7

# %%
print("{:.2f} {:.2f}".format(3.3535,2424.2424))
# Out:
# 3.35 2424.24

# %%
liste = [3223,23523,2353.23523,"fdf","dgdsgds"]

# %%
type(liste)
# Out:
# list

# %%
liste
# Out:
# [3223, 23523, 2353.23523, 'fdf', 'dgdsgds']

# %%
liste2 = list()

# %%
liste2
# Out:
# []

# %%
len(liste)
# Out:
# 5

# %%
liste3 = list("Merhaba")

# %%
liste3
# Out:
# ['M', 'e', 'r', 'h', 'a', 'b', 'a']

# %%
liste3[2]
# Out:
# 'r'

# %%
liste3[len(liste3)-1]
# Out:
# 'a'

# %%
liste3[::-2]
# Out:
# ['a', 'a', 'r', 'M']

# %%
liste4 = [1,2,3,4,5]
liste5 = [6,7,8,9]
liste6 = liste4 + liste5

# %%
liste6 = liste6 *3

# %%
liste6
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
liste4[2] = 33

# %%
liste4
# Out:
# [20, 21, 2, 2, 2, 3, 3, 33, 4, 5]

# %%
liste4[:2]
# Out:
# [1, 2]

# %%
liste4[:2] = [20,21,2]

# %%
liste7 = list("Batuhan")

# %%
liste7.append(2,1)

# %%
liste7
# Out:
# ['B', 'a', 't', 'u', 'h', 'a', 'n', 2]

# %%
liste7.pop(1)
# Out:
# 'a'

# %%
liste7
# Out:
# ['B', 't', 'u', 'h', 'a', 'n']

# %%
liste8 = [37,142,271,146,1,3,72,9,0,-1]

# %%
liste8.sort(reverse=True)

# %%
liste8
# Out:
# [271, 146, 142, 72, 37, 9, 3, 1, 0, -1]

# %%
liste9 = ["a","A","B","bB","ba","90999","."]

# %%
liste9.sort()

# %%
liste9
# Out:
# ['.', '90999', 'A', 'B', 'a', 'bB', 'ba']

# %%
liste10 = [[24,224],[35,52],[12,53]]

# %%
liste10
# Out:
# [[24, 224], [35, 52], [12, 53]]

# %%
liste10[2][1]
# Out:
# 53
