# %%
i = 0
while i < 10:
    print(i)
    if i == 5:
        break
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
while True:
    x = input("Çıkmak için q yaz")
    if x == "q":
        print("Bye")
        break
    print("Programdan çıkılmadı")
# Out:
# Programdan çıkılmadı
# Programdan çıkılmadı
# Bye

# %%
for i in range(10):
    if i == 5:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
i = 0
while i < 10:
    if i == 2 or i == 3:
        i+=1
        print("Boşluk")
        continue
    print(i)
    i += 1
# Out:
# 0
# 1
# Boşluk
# Boşluk
# 4
# 5
# 6
# 7
# 8
# 9
