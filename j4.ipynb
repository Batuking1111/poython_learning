# %%
input()
# Out:
# '56'

# %%
input("Sayı gir")
# Out:
# '45645'

# %%
x = input("Gir")
print("Girilen değer:",x,sep="")
# Out:
# Girilen değer:46

# %%
y = input("hir")
print(type(y))
# Out:
# <class 'str'>

# %%
z = int(input("gggiiirr"))
print(z*3)
# Out:
# 9

# %%
isim = input("İsmini gir")
print("İsminiz:",isim)
# Out:
# İsminiz: Batuhan
