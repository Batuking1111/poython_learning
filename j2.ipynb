# %%
demet = (1,2,3,4,5,6,7,8,9)

# %%
type(demet)
# Out:
# tuple

# %%
demet[4]
# Out:
# 5

# %%
demet2 = (1,1,1,1,2,2,2,3,3,4)

# %%
demet2.count(2)
# Out:
# 3

# %%
demet3 = ("Batu","Han","Erkan")

# %%
demet3.index("Batu")
# Out:
# 0
