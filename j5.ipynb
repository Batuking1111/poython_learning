# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
b= False

# %%
type(b)
# Out:
# bool

# %%
bool(0.00000000000000000000)
# Out:
# False

# %%
0.3+0.4
# Out:
# 0.7

# %%
c = None

# %%
type(c)
# Out:
# NoneType

# %%
c = 4

# %%
2 == 3
# Out:
# False

# %%
3 <= 3
# Out:
# True

# %%
True or False
# Out:
# True

# %%
1 < 2 or "Batu" < "Ab" or 1 == 1/0
# Out:
# True

# %%
x = 1

# %%
x
# Out:
# 1

# %%
a = 1==1

# %%
a
# Out:
# True

# %%
not a
# Out:
# False
